# %%
import land
import pandas as pd
import zipfile
import numpy as np
import io
from io import BufferedReader
from matplotlib.colors import ListedColormap
from matplotlib import pyplot as plt
import time
from IPython.core.display import HTML
c = land.open("images")

# %%
t1 = time.time()
html = c.animate("eauclaire")
t2 = time.time()
HTML(html)
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
t2 - t1
# Out:
# 13.376154661178589

# %%
t1 = time.time()
c.lat_regression(41,None)
t2 = time.time()

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Latitude')
ax.set_ylabel('Deciduous forest %')
c.lat_regression(41,ax)
# Out:
# (5.965578948401941, -243.38363729644226)

# %%
fig, ax = plt.subplots()
ax.set_ylabel("Developed")
ax.set_xlabel("Year")
c.year_regression("madison", [21,22,23,24], ax)
# Out:
# (0.3368827825670495, -651.1939541427197)

# %%
t2-t1
# Out:
# 1.1454577445983887
